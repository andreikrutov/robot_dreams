# %% [markdown]
# # Домашнее задание
# # Описательная статистика

# %% [markdown]
# ## Часть 1 - чистые данные

# %% [markdown]
# Библиотека seaborn работает с некоторыми известными датасетами, на которых мы можем опробовать описательный анализ данных.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Мы выбрали датасет mpg, описывающий некоторые из машин бывших в продаже на американском рынке. Довольно интересная информация здесь - характеристика mpg - miles per gallon, сколько миль автомобиль может проехать на галлоне бензина.

# %%
data=sns.load_dataset('mpg')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Задача 1

# %% [markdown]
# ### 1.1 Посчитайте среднее значение mpg

# %% [markdown]
# Для этого существуют разные способы. Один из них связан с возможностями библиотеки пандас. Прочитайте секцию о описательной статистике (descriptive statistics) по следующей ссылке : https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html

# %%
data['mpg'].mean()
# Out:
# 23.514572864321615

# %% [markdown]
# ### 1.2 Посчитайте медиану mpg

# %%
data['mpg'].median()
# Out:
# 23.0

# %% [markdown]
# ## Задача 2

# %% [markdown]
# ### Нарисуйте гистограмму величины мpg, используя seaborn.

# %%
_ = sns.histplot(data = data, x = 'mpg')

# %% [markdown]
# ## Задача 3

# %% [markdown]
# ### 3.1 Нарисуйте 3 ящика с усами, показывающие распределение mpg в зависимости от региона, в котором машина была произведена

# %% [markdown]
# Используйте boxplot, давая две переменные х и y. Если вам нужна будет помощь, посмотрите информацию по ссылке: https://seaborn.pydata.org/examples/index.html

# %%
_ = sns.boxplot(x = 'origin', y = 'mpg', data = data, orient = 'v')

# %% [markdown]
# ### 3.2 Нарисуйте ящики с усами, показывающие распределение mpg, в зависимости от количества цилиндров автомобиля

# %%
_ = sns.boxplot(x = 'cylinders', y = 'mpg', data = data, orient = 'v')

# %% [markdown]
# ## Задача 4

# %% [markdown]
# ### 4.1 Нарисуйте scatter plot количества лошадинных сил против рабочего объема. Что вы думаете об их связи между собой?

# %%
_ = sns.scatterplot(x = 'displacement', y = 'horsepower', data = data)

# %% [markdown]
# Наблюдается прямая корреляция. Чем выше рабочий объем двигателя, тем больше у него лошадиных сил.

# %% [markdown]
# ### 4.2 Нарисуйте scatter plot  рабочего объема против mpg. Что вы думаете об их связи между собой?

# %%
_ = sns.scatterplot(x = 'mpg', y = 'displacement', data = data)

# %% [markdown]
# У этих параметров обратная корреляция. Чем выше объем двигателя, тем меньшее расстояние может прохеать автомобиль на одном и том же количестве топлива.

# %% [markdown]
# ### 4.3 Нарисуйте scatter plot  рабочего объема против mpg и покрасьте пункты в зависимости от страны производства автомобиля (hue=...).  Что вы думаете?

# %%
_ = sns.scatterplot(x = 'mpg', y = 'displacement', data = data, hue = 'origin')

# %% [markdown]
# Самые экономичные автомобили производят в Японии. Самые мощные и неэкономные - в США

# %% [markdown]
# ## Часть 2 - Данные из бизнеса

# %% [markdown]
# ## Задача 5

# %% [markdown]
# Прочитайте данные к уроку ('listings.csv') в пандас dataframe и покажите их голову. Это данные от AirBnB, описывающие часть квартир и комнат на сдачу в Амстердаме.

# %%
df = pd.read_csv('d://robot_dreams/math for DS/listings.csv')

# %% [markdown]
# ## Задача 6

# %%
df.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  25428    Lovely, spacious 1 bed apt in Center(with lift)    56142
# 3  27886  Romantic, stylish B&B houseboat in canal district    97647
# 4  28871                            Comfortable double room   124245
#
#    host_name  neighbourhood_group                           neighbourhood  \
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Joan                  NaN                            Centrum-West
# 3       Flip                  NaN                            Centrum-West
# 4      Edwin                  NaN                            Centrum-Oost
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  52.36575    4.94142     Private room     59               3
# 1  52.36509    4.89354     Private room    129               1
# 2  52.37297    4.88339  Entire home/apt    125              14
# 3  52.38761    4.89188     Private room    125               2
# 4  52.36610    4.88953     Private room     75               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                278  2020-02-14               1.92
# 1                339  2020-04-09               2.54
# 2                  5  2020-02-09               0.13
# 3                219  2020-07-25               1.98
# 4                336  2020-09-20               2.63
#
#    calculated_host_listings_count  availability_365
# 0                               1               139
# 1                               2                 0
# 2                               1               251
# 3                               1               136
# 4                               2               338

# %% [markdown]
# ### 6.1 Используя countplot, ответьте на вопрос:
# ### Какой тип комнаты самый распространенный в Амстердаме? https://seaborn.pydata.org/generated/seaborn.countplot.html

# %%
_ = sns.countplot(x = 'room_type', data = df)

# %% [markdown]
# Самый распространенный - Entire home/apt

# %% [markdown]
# ### 6.2 Нарисуйте ящики с усами, показывающие распределение цены в зависимости от района, в котором находится квартира/комната. Видите ли вы проблему?

# %%
fig, ax = plt.subplots(figsize=(20,10))
_ = sns.boxplot(x = 'price', y = 'neighbourhood', data = df)

# %% [markdown]
# Много выбросов в данных. При дальнейшем анализе придется каким-то образом их обрабатывать.
#
# Выбросы также приводят к проблеме с отображением данных, очень сложно подобрать адекватный масштаб.

# %% [markdown]
# ### 6.3 Нарисуйте ящики с усами, показывающие распределение цены в зависимости от района, в котором находится квартира/комната, используйте следующую команду в boxplot showfliers=False. Что изменилось?

# %%
fig, ax = plt.subplots(figsize=(20,10))
_ = sns.boxplot(x = 'price', y = 'neighbourhood', data = df, showfliers=False)

# %% [markdown]
# showfliers=False убирает выбросы из данных, проблема с отображением исчезла.

# %% [markdown]
# ### 6.4 Нарисуйте для каждого типа комнаты (room_type) ящики с усами, показывающие распределение цены в зависимости от района, в котором находится квартира/комната.

# %% [markdown]
# Для этого можно использовать функцию catplot и задать, что мы хотим показать некоторые ящики kind='box', задать какая переменная будет в х и y, что переменная room_type будет делить график на колонки col='room_type', и что мы хотим, чтобы после 2-х колонок произошел переход на следующую строку: col_wrap=2.

# %%
_ = sns.catplot(y = 'room_type', x = 'price', data = df, kind='box', col='room_type', col_wrap=2)

# %%
select = (df['room_type']=='Entire home/apt') & (df['price']<200)

# %% [markdown]
# ### 6.5 Создайте гистограмму цен для самого распространенного типа комнат в Амстердаме. С какими проблемами вы столкнулись?

# %%
select_df = df[(df['room_type']=='Entire home/apt')&(df['price']<200)]
select_df.head(3)
# Out:
#       id                                             name  host_id host_name  \
# 2  25428  Lovely, spacious 1 bed apt in Center(with lift)    56142      Joan
# 7  41125                Amsterdam Center Entire Apartment   178515     Fatih
# 9  44129                    Luxury design with canal view   187728   Tatiana
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 2                  NaN  Centrum-West  52.37297    4.88339  Entire home/apt
# 7                  NaN  Centrum-West  52.37891    4.88321  Entire home/apt
# 9                  NaN  Centrum-West  52.38071    4.88610  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 2    125              14                  5  2020-02-09               0.13
# 7    160               4                 89  2020-02-10               0.72
# 9    115               4                179  2021-01-01               1.40
#
#    calculated_host_listings_count  availability_365
# 2                               1               251
# 7                               1                 0
# 9                               1               117

# %%
_ = sns.histplot(x = 'price', data = select_df)
